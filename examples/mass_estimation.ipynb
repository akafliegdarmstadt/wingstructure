# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from wingstructure import WingExt, LiftAnalysis, LiftAndMomentAnalysis
import numpy as np
import copy
from wingstructure.structure import WingSection

# %% [markdown]
# ## wing definition

# %%
span_positions = [0, 2, 5, 7]
chord_lengths = [1, 0.9, 0.6, 0.3]
offsets = [0, 0.1, 0.4, 0.7]
twists = [0]*4
airfoils = ['ah93157']*4

wing = WingExt.create_from_planform(span_positions, chord_lengths, offsets, twists, airfoils);
wing.set_root_pos(0.7)
wing.set_airbrake(1,2.3)

wing.set_flap('QR',2,0.3,5,0.2)
wing.set_flap('QR2', 5, 0.2, 7, 0.2)
wing.plot()

coords = np.loadtxt('ah93157.dat', skiprows=1)

# %%
skins = ( 
            {
                'thickness': 2e-3, #m
                'rho': 30 # kg/m^3
            },
            {
                'thickness': 10e-3, #m
                'rho': 120, # kg/m^3
                'chord-bounds': (0.1, 0.3), #bounds/chord_length
                'span-bounds': (0, 4), # m halfspanwidth
            },
            {
                'thickness': 5e-3, #m
                'rho': 120, # kg/m^3
                'chord-bounds': (0.1, 0.3), #bounds/chord_length
                'span-bounds': (4, 7), # m halfspanwidth
            },
            {
                'thickness': 10e-3, #m
                'rho': 30, # kg/m^3
                'chord-bounds': (0.5, 0.7),
            },
            {
                'thickness': 1.5e-3, #m
                'rho': 30 #kg/m^3
            },
            {
                'thickness': 1.5e-3, #m
                'rho': 30 #kg/m^3
            },
        )

spar = {
            'flange_thickness': 10e-3, #m
            'position': 0.4, # position/chord_length
            'flange_width': 0.07, # width/chord_length
            'flange_rho': 30, #kg/m^3
            'web_position': 0.45, # position/chord_length
            'web_thickness': 7e-3, #m
            'web_rho': 30, #kg/m^3
        }

trailing_web = {
            'thickness': 10e-3, #m
            'offset': 3e-3, #m
            'rho': 30, #kg/m^3
        }

wingsec = WingSection(wing, {'ah93157':coords}, skins, spar, trailing_web)

# %%
wingsec.update_geometry(wing.root_pos)
# Out:
# Iteration 0: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_0
# Iteration 1: type=<class 'shapely.geometry.polygon.LinearRing'>
#  create reinforcement part_skin_1
#   bounds: [ 0.0965  0.2895]
#    thickness:0.01
# create part_skin_1_upper
# create part_skin_1_lower
# Iteration 2: type=<class 'shapely.geometry.polygon.LinearRing'>
# Iteration 3: type=<class 'shapely.geometry.polygon.LinearRing'>
#  create reinforcement part_skin_3
#   bounds: [ 0.4825  0.6755]
#    thickness:0.01
# create part_skin_3_upper
# create part_skin_3_lower
# Iteration 4: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_4
# Iteration 5: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_5
#  create reinforcement flange
#   bounds: [ 0.352225  0.45355 ]
#    thickness:0.01
# create flange_upper
# create flange_lower

# %%
wingsec.plot()

# %%
wingsec.inter.bounds
# Out:
# (0.35222499999999995, -0.034757996386767846, 0.45355, 0.10660217789199293)

# %%
last = None

volume = 0.0

for ii,y in enumerate(np.linspace(wing.root_pos, wing.span_width()/2, 5)):
    print('\nSchnitt: {}'.format(ii))
    wingsec.update_geometry(y)
    current = wingsec.area
    if last:
        volume += (current+last)/2 * (y-ylast)
    last = current
    ylast = y
    plt.figure(ii)
    wingsec.plot()
# Out:
# Schnitt: 0
# Iteration 0: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_0
# Iteration 1: type=<class 'shapely.geometry.polygon.LinearRing'>
#  create reinforcement part_skin_1
#   bounds: [ 0.0965  0.2895]
#    thickness:0.01
# create part_skin_1_upper
# create part_skin_1_lower
# Iteration 2: type=<class 'shapely.geometry.polygon.LinearRing'>
# Iteration 3: type=<class 'shapely.geometry.polygon.LinearRing'>
#  create reinforcement part_skin_3
#   bounds: [ 0.4825  0.6755]
#    thickness:0.01
# create part_skin_3_upper
# create part_skin_3_lower
# Iteration 4: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_4
# Iteration 5: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_5
#  create reinforcement flange
#   bounds: [ 0.352225  0.45355 ]
#    thickness:0.01
# create flange_upper
# create flange_lower
#
# Schnitt: 1
# Iteration 0: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_0
# cut flap
# Iteration 1: type=<class 'shapely.geometry.polygon.LinearRing'>
#  create reinforcement part_skin_1
#   bounds: [ 0.08725  0.26175]
#    thickness:0.01
# create part_skin_1_upper
# create part_skin_1_lower
# Iteration 2: type=<class 'shapely.geometry.polygon.LinearRing'>
# Iteration 3: type=<class 'shapely.geometry.polygon.LinearRing'>
#  create reinforcement part_skin_3
#   bounds: [ 0.43625  0.61075]
#    thickness:0.01
# create part_skin_3_upper
# create part_skin_3_lower
# Iteration 4: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_4
# cut flap
# Iteration 5: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_5
# cut flap
#  create reinforcement flange
#   bounds: [ 0.3184625  0.410075 ]
#    thickness:0.01
# create flange_upper
# create flange_lower
# ajsdföjsad:Polygon
#
# Schnitt: 2
# Iteration 0: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_0
# cut flap
# Iteration 1: type=<class 'shapely.geometry.polygon.LinearRing'>
#  create reinforcement part_skin_1
#   bounds: [ 0.0715  0.2145]
#    thickness:0.01
# create part_skin_1_upper
# create part_skin_1_lower
# Iteration 2: type=<class 'shapely.geometry.polygon.LinearRing'>
# Iteration 3: type=<class 'shapely.geometry.polygon.LinearRing'>
#  create reinforcement part_skin_3
#   bounds: [ 0.3575  0.5005]
#    thickness:0.01
# create part_skin_3_upper
# create part_skin_3_lower
# Iteration 4: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_4
# cut flap
# Iteration 5: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_5
# cut flap
#  create reinforcement flange
#   bounds: [ 0.260975  0.33605 ]
#    thickness:0.01
# create flange_upper
# create flange_lower
# ajsdföjsad:Polygon
#
# Schnitt: 3
# Iteration 0: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_0
# cut flap
# Iteration 1: type=<class 'shapely.geometry.polygon.LinearRing'>
# Iteration 2: type=<class 'shapely.geometry.polygon.LinearRing'>
#  create reinforcement part_skin_2
#   bounds: [ 0.053625  0.160875]
#    thickness:0.005
# create part_skin_2_upper
# create part_skin_2_lower
# Iteration 3: type=<class 'shapely.geometry.polygon.LinearRing'>
#  create reinforcement part_skin_3
#   bounds: [ 0.268125  0.375375]
#    thickness:0.01
# create part_skin_3_upper
# create part_skin_3_lower
# Iteration 4: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_4
# cut flap
# Iteration 5: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_5
# cut flap
#  create reinforcement flange
#   bounds: [ 0.19573125  0.2520375 ]
#    thickness:0.01
# create flange_upper
# create flange_lower
# ajsdföjsad:Polygon
#
# Schnitt: 4
# Iteration 0: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_0
# cut flap
# Iteration 1: type=<class 'shapely.geometry.polygon.LinearRing'>
# Iteration 2: type=<class 'shapely.geometry.polygon.LinearRing'>
# Iteration 3: type=<class 'shapely.geometry.polygon.LinearRing'>
#  create reinforcement part_skin_3
#   bounds: [ 0.15  0.21]
#    thickness:0.01
# create part_skin_3_upper
# create part_skin_3_lower
# Iteration 4: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_4
# cut flap
# Iteration 5: type=<class 'shapely.geometry.polygon.LinearRing'>
# create skin_5
# cut flap
#  create reinforcement flange
#   bounds: [ 0.1095  0.141 ]
#    thickness:0.01
# create flange_upper
# create flange_lower
# ajsdföjsad:Polygon

# %%
from shapely.geometry import LineString, Polygon

LineString([[0,0],[1,1]]).intersection(LineString([[0,1],[1,0]]))

# %%
line = LineString(([0,0],[1,1]))
poly = Polygon([[0,0],[1,0],[0,1]])
poly.intersection(line).length, line.length
# Out:
# (0.7071067811865476, 1.4142135623730951)

# %%
line.coords[0:2]
# Out:
# [(0.0, 0.0), (1.0, 1.0)]
